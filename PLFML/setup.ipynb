# %%
# Project settings - defining basic configuration for the project
settings = {
    "project_name": "PLF_mL",  # Name of the project
    "project_dir": "./",  # Absolute path where the project is located (e.g., "/home/user/project_folder")
    "component_dir": "./MLComps"  # Absolute path to the directory where machine learning components are stored (e.g., "/home/user/project_folder/MLComps")
}

# %%
# Importing the `create_project` function from the `plf.lab` module
from plf.lab import create_project

# %%
# Calling the `create_project` function to initialize the project
# The function will create necessary project directories and files based on the settings.
# It returns the path where the project has been initialized, which will be needed for accessing
# the lab in subsequent Jupyter notebooks.
create_project(settings=settings)
# Out:
# '/mnt/work/stdML/ExperQuick/PLFML/PLF_mL/PLF_mL.json'
